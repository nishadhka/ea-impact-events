# %%
from dotenv import load_dotenv
import os

load_dotenv()

csv_data_path=os.getenv("impact_data_dataframe_path")

shpfile_path=os.getenv("impact_data_dataframe_path")

# %%
import pandas as pd
import numpy as np
import re



em_data_filepath=f'{csv_data_path}emdat_public_2022_08_11_query_uid-IKGfZc.xlsx'

dfb = pd.read_excel(em_data_filepath, engine='openpyxl',skiprows=6,sheet_name = 'emdat data')



flood_grp=['Flood']

#dfb1_ea=dfb1[dfb1['Country'].str.contains(ea_cntr)]
dfb_fl=dfb[dfb['Disaster Type'].isin(flood_grp)]

ea_cntr=['Djibouti', 'Eritrea','Ethiopia','Kenya','Rwanda', 'Somalia','South Sudan','Sudan (the)','Tanzania, United Republic of']

#dfb1_ea=dfb1[dfb1['Country'].str.contains(ea_cntr)]
dfb_fl_ea=dfb_fl[dfb_fl['Country'].isin(ea_cntr)]
#dfb_fl_ea.info()
dfb_fl_ea_map=dfb_fl_ea[['Dis No','Year','Country','ISO','Location']]
dfb_fl_ea_map['loc_str1'] = dfb_fl_ea_map['Location'].str.replace(' and ',',')
dfb_fl_ea_map['loc_str2'] = dfb_fl_ea_map['loc_str1'].str.replace(' & ',',')
dfb_fl_ea_map['loc_str3'] = dfb_fl_ea_map['loc_str2'].str.replace('&',',')
dfb_fl_ea_map['loc_str4'] = dfb_fl_ea_map['loc_str3'].str.replace(';',',')

dfb_fl_ea_map['loc_list'] = dfb_fl_ea_map['loc_str4'].str.split(',')
df_fl=dfb_fl_ea_map.explode('loc_list')
df_fl['row_idx']=np.core.defchararray.add('fl_', np.arange(0,len(df_fl.index),1).astype(str))

#df1_fl['loc_list_a'] = df1_fl['loc_list'].str.replace(r' \s', '', regex=True)
df1_fl=df_fl[['Dis No','Year','Country','ISO','loc_list','Location','row_idx']]
df2_fl=df1_fl.reset_index()

for idx,row in df2_fl.iterrows():
    #space_rmvd_str=re.sub(r"^\s", '', str(row['loc_list_a']), flags=re.IGNORECASE)
    #print(space_rmvd_str,row['loc_list_a'])
    df2_fl.loc[idx,'loc_list_a']= re.sub(r"^\s", '', str(row['loc_list']), flags=re.IGNORECASE)
    
df3_fl=df2_fl[['Dis No','Year','Country','ISO','loc_list','loc_list_a','Location','row_idx']]

#df3_fl.to_csv(f'{csv_data_path}ea_flood_location.csv',index=False)
#d
#df3_fl.info()


# db=pd.read_csv(f'{csv_data_path}ea_flood_missing_location.csv')

# db['code']=db['Dis No'].str.split('-').str[-1]

# db['loc_list'] = db['Location'].str.split(',')
# db1=db.explode('loc_list')
# #db2=db1.drop_duplicates('loc_list')

# db2=db1.drop_duplicates('code')
# code_list=db2['code'].tolist()
# db1.to_csv(f'{csv_data_path}ea_flood_missing_location_v1.csv')
# Out:
# /opt/conda/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
dfb_fl_ea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269 entries, 33 to 4631
# Data columns (total 50 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Dis No                                     269 non-null    object
#  1   Year                                       269 non-null    int64
#  2   Seq                                        269 non-null    int64
#  3   Glide                                      53 non-null     object
#  4   Disaster Group                             269 non-null    object
#  5   Disaster Subgroup                          269 non-null    object
#  6   Disaster Type                              269 non-null    object
#  7   Disaster Subtype                           204 non-null    object
#  8   Disaster Subsubtype                        0 non-null      object
#  9   Event Name                                 0 non-null      object
#  10  Country                                    269 non-null    object
#  11  ISO                                        269 non-null    object
#  12  Region                                     269 non-null    object
#  13  Continent                                  269 non-null    object
#  14  Location                                   265 non-null    object
#  15  Origin                                     190 non-null    object
#  16  Associated Dis                             48 non-null     object
#  17  Associated Dis2                            6 non-null      object
#  18  OFDA Response                              15 non-null     object
#  19  Appeal                                     24 non-null     object
#  20  Declaration                                24 non-null     object
#  21  Aid Contribution                           21 non-null     float64
#  22  Dis Mag Value                              104 non-null    float64
#  23  Dis Mag Scale                              269 non-null    object
#  24  Latitude                                   75 non-null     object
#  25  Longitude                                  75 non-null     object
#  26  Local Time                                 0 non-null      object
#  27  River Basin                                93 non-null     object
#  28  Start Year                                 269 non-null    int64
#  29  Start Month                                269 non-null    float64
#  30  Start Day                                  240 non-null    float64
#  31  End Year                                   269 non-null    int64
#  32  End Month                                  269 non-null    float64
#  33  End Day                                    244 non-null    float64
#  34  Total Deaths                               201 non-null    float64
#  35  No Injured                                 45 non-null     float64
#  36  No Affected                                201 non-null    float64
#  37  No Homeless                                55 non-null     float64
#  38  Total Affected                             239 non-null    float64
#  39  Reconstruction Costs ('000 US$)            2 non-null      float64
#  40  Reconstruction Costs, Adjusted ('000 US$)  2 non-null      float64
#  41  Insured Damages ('000 US$)                 1 non-null      float64
#  42  Insured Damages, Adjusted ('000 US$)       1 non-null      float64
#  43  Total Damages ('000 US$)                   31 non-null     float64
#  44  Total Damages, Adjusted ('000 US$)         31 non-null     float64
#  45  CPI                                        264 non-null    float64
#  46  Adm Level                                  215 non-null    object
#  47  Admin1 Code                                99 non-null     object
#  48  Admin2 Code                                138 non-null    object
#  49  Geo Locations                              215 non-null    object
# dtypes: float64(18), int64(4), object(28)
# memory usage: 107.2+ KB

# %%
db=pd.read_csv(f'{csv_data_path}ea_flood_missing_location.csv')

db['code']=db['Dis No'].str.split('-').str[-1]

db['loc_list'] = db['Location'].str.split(',')
db1=db.explode('loc_list')
#db2=db1.drop_duplicates('loc_list')

db2=db1.drop_duplicates('code')
code_list=db2['code'].tolist()
#db1.to_csv(f'{csv_data_path}ea_flood_missing_location_v1.csv')

# %%
db2
# Out:
#            Dis No                                           Location code  \
# 0   1993-0005-TZA          Lushoto, Korogwe districts (Tanga region)  TZA
# 3   1994-0507-DJI  Djibouti city, Holhol, Ali Addeh, Tadjoura dis...  DJI
# 4   1994-0194-ETH  North Shoa, South Welo, Tach Gayint district (...  ETH
# 8   1996-0474-KEN                                    Nyanza province  KEN
# 12  1994-0217-SDN  El Fasher, Nyala (Darfur state), Hamrat El Wiz...  SDN
# 13  1994-0573-SOM                                              South  SOM
#
#            loc_list
# 0           Lushoto
# 3     Djibouti city
# 4        North Shoa
# 8   Nyanza province
# 12        El Fasher
# 13            South

# %%
import geopandas as gp


gaul_adm2=gp.read_file(f'{shpfile_path}ea_adm2_gaul.shp')

# %%
gaul_adm2
# Out:
#      gml_id    fid  ADM2_CODE        ADM2_NAME  ADM1_CODE    ADM1_NAME  \
# 0      None     20      32854    Al Mahabishah       3418       Hajjah
# 1      None   8004      12847           Ouadda        856  Haute-Kotto
# 2      None   8005      12848          Yalinga        856  Haute-Kotto
# 3      None     57      32877      Al Makhadir       3419          Ibb
# 4      None     59      32853        Al Miftah       3418       Hajjah
# ...     ...    ...        ...              ...        ...          ...
# 1449   None  33989      32849              Abs       3418       Hajjah
# 1450   None  34013      32850   Aflah Al Yaman       3418       Hajjah
# 1451   None  34019      32851  Aflah Ash Shawm       3418       Hajjah
# 1452   None  34039      32852       Al Jamimah       3418       Hajjah
# 1453   None  34141      32855     Al Maghrabah       3418       Hajjah
#
#             STATUS DISP_AREA  ADM0_CODE                 ADM0_NAME  \
# 0     Member State        NO        269                     Yemen
# 1     Member State        NO         49  Central African Republic
# 2     Member State        NO         49  Central African Republic
# 3     Member State        NO        269                     Yemen
# 4     Member State        NO        269                     Yemen
# ...            ...       ...        ...                       ...
# 1449  Member State        NO        269                     Yemen
# 1450  Member State        NO        269                     Yemen
# 1451  Member State        NO        269                     Yemen
# 1452  Member State        NO        269                     Yemen
# 1453  Member State        NO        269                     Yemen
#
#                                                geometry
# 0     MULTIPOLYGON (((43.45552 15.97692, 43.45554 15...
# 1     POLYGON ((23.28750 8.76171, 23.28112 8.75005, ...
# 2     POLYGON ((24.27220 8.27699, 24.27390 8.27343, ...
# 3     POLYGON ((44.26976 14.20502, 44.26981 14.20496...
# 4     POLYGON ((43.54572 15.97740, 43.55705 15.97485...
# ...                                                 ...
# 1449  POLYGON ((43.22042 16.18735, 43.22144 16.18402...
# 1450  POLYGON ((43.44169 15.98401, 43.44304 15.98109...
# 1451  POLYGON ((43.43349 16.07773, 43.43851 16.07462...
# 1452  POLYGON ((43.57590 16.09728, 43.57911 16.09281...
# 1453  POLYGON ((43.70865 15.93842, 43.70853 15.93832...
#
# [1454 rows x 11 columns]

# %%
import geopandas as gp
import pandas as pd

adm0=gp.read_file(f'{shpfile_path}ea_adm0_geoboundaries.shp')
adm1=gp.read_file(f'{shpfile_path}a_adm1_geoboundaries.shp')
adm2=gp.read_file(f'{shpfile_path}ea_adm2_geoboundaries.shp')

db=pd.concat([adm0,adm1,adm2])

db1=db.drop_duplicates('shapeID')
db1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 1155 entries, 0 to 971
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   shapeName   1155 non-null   object
#  1   shapeISO    1151 non-null   object
#  2   shapeID     1155 non-null   object
#  3   shapeGroup  1155 non-null   object
#  4   shapeType   1155 non-null   object
#  5   geometry    1155 non-null   geometry
# dtypes: geometry(1), object(5)
# memory usage: 63.2+ KB

# %%
db1=db[db['shapeGroup']=='SDN']
#db1.shapeName.tolist()
db2=db1.sort_values('shapeName')
db3=db2[['shapeName','shapeType','shapeID']]
pd.set_option('display.max_columns', 4)
pd.set_option('display.max_rows', 200)
print(db3)
# Out:
#                 shapeName shapeType              shapeID
# 522             Abu Hamed      ADM2    SDN-ADM2-3_0_0-B8
# 544            Abu Houjar      ADM2   SDN-ADM2-3_0_0-B30
# 654             Abu Jabra      ADM2  SDN-ADM2-3_0_0-B140
# 576           Abu Jubaiha      ADM2   SDN-ADM2-3_0_0-B62
# 624           Abu Karinka      ADM2  SDN-ADM2-3_0_0-B110
# 650             Abu Zabad      ADM2  SDN-ADM2-3_0_0-B136
# 640        Abyei - Muglad      ADM2  SDN-ADM2-3_0_0-B126
# 584        Abyei PCA Area      ADM2   SDN-ADM2-3_0_0-B70
# 655                 Adila      ADM2  SDN-ADM2-3_0_0-B141
# 567                  Agig      ADM2   SDN-ADM2-3_0_0-B53
# 635               Ailliet      ADM2  SDN-ADM2-3_0_0-B121
# 583              Al Buram      ADM2   SDN-ADM2-3_0_0-B69
# 531               Al Daba      ADM2   SDN-ADM2-3_0_0-B17
# 680             Al Mafaza      ADM2  SDN-ADM2-3_0_0-B166
# 644                Al Qoz      ADM2  SDN-ADM2-3_0_0-B130
# 643              Al Sunut      ADM2  SDN-ADM2-3_0_0-B129
# 588            Al Tadamon      ADM2   SDN-ADM2-3_0_0-B74
# 528              Alborgag      ADM2   SDN-ADM2-3_0_0-B14
# 530               Algolid      ADM2   SDN-ADM2-3_0_0-B16
# 620               Alwehda      ADM2  SDN-ADM2-3_0_0-B106
# 675                 Aroma      ADM2  SDN-ADM2-3_0_0-B161
# 629              Assalaya      ADM2  SDN-ADM2-3_0_0-B115
# 526                Atbara      ADM2   SDN-ADM2-3_0_0-B12
# 676          Atbara River      ADM2  SDN-ADM2-3_0_0-B162
# 589                  Azum      ADM2   SDN-ADM2-3_0_0-B75
# 641              Babanusa      ADM2  SDN-ADM2-3_0_0-B127
# 627          Bahr El Arab      ADM2  SDN-ADM2-3_0_0-B113
# 534                  Bara      ADM2   SDN-ADM2-3_0_0-B20
# 527                Barbar      ADM2   SDN-ADM2-3_0_0-B13
# 570               Basonda      ADM2   SDN-ADM2-3_0_0-B56
# 587                   Bau      ADM2   SDN-ADM2-3_0_0-B73
# 590                 Beida      ADM2   SDN-ADM2-3_0_0-B76
# 628                Bielel      ADM2  SDN-ADM2-3_0_0-B114
# 591               Bindisi      ADM2   SDN-ADM2-3_0_0-B77
# 135       Blue Nile State      ADM1   SDN-ADM1-3_0_0-B16
# 659                 Buram      ADM2  SDN-ADM2-3_0_0-B145
# 129        Central Darfur      ADM1   SDN-ADM1-3_0_0-B10
# 663                 Dalgo      ADM2  SDN-ADM2-3_0_0-B149
# 592          Dar El Salam      ADM2   SDN-ADM2-3_0_0-B78
# 579               Dilling      ADM2   SDN-ADM2-3_0_0-B65
# 638                 Dimsu      ADM2  SDN-ADM2-3_0_0-B124
# 529               Dongola      ADM2   SDN-ADM2-3_0_0-B15
# 674                Dordeb      ADM2  SDN-ADM2-3_0_0-B160
# 128     East Darfur State      ADM1    SDN-ADM1-3_0_0-B9
# 574    Eastern El Galabat      ADM2   SDN-ADM2-3_0_0-B60
# 540     Eastern El Gezira      ADM2   SDN-ADM2-3_0_0-B26
# 548        Eastern Sennar      ADM2   SDN-ADM2-3_0_0-B34
# 616              Ed Daein      ADM2  SDN-ADM2-3_0_0-B102
# 525              Ed Damer      ADM2   SDN-ADM2-3_0_0-B11
# 617          Ed El Fursan      ADM2  SDN-ADM2-3_0_0-B103
# 646           El Abassiya      ADM2  SDN-ADM2-3_0_0-B132
# 678             El Butana      ADM2  SDN-ADM2-3_0_0-B164
# 546               El Dali      ADM2   SDN-ADM2-3_0_0-B32
# 671           El Damazine      ADM2  SDN-ADM2-3_0_0-B157
# 652             El Dindir      ADM2  SDN-ADM2-3_0_0-B138
# 550             El Douiem      ADM2   SDN-ADM2-3_0_0-B36
# 568            El Fashaga      ADM2   SDN-ADM2-3_0_0-B54
# 593             El Fasher      ADM2   SDN-ADM2-3_0_0-B79
# 679                El Faw      ADM2  SDN-ADM2-3_0_0-B165
# 657            El Ferdous      ADM2  SDN-ADM2-3_0_0-B143
# 594            El Geneina      ADM2   SDN-ADM2-3_0_0-B80
# 555            El Gutaina      ADM2   SDN-ADM2-3_0_0-B41
# 541          El Hasaheesa      ADM2   SDN-ADM2-3_0_0-B27
# 556           El Jabalian      ADM2   SDN-ADM2-3_0_0-B42
# 542            El Kamleen      ADM2   SDN-ADM2-3_0_0-B28
# 595               El Kuma      ADM2   SDN-ADM2-3_0_0-B81
# 665             El Kurmuk      ADM2  SDN-ADM2-3_0_0-B151
# 596              El Malha      ADM2   SDN-ADM2-3_0_0-B82
# 543           El Manageel      ADM2   SDN-ADM2-3_0_0-B29
# 523           El Matammah      ADM2    SDN-ADM2-3_0_0-B9
# 651             El Nehoud      ADM2  SDN-ADM2-3_0_0-B137
# 565              El Qaneb      ADM2   SDN-ADM2-3_0_0-B51
# 569            El Quresha      ADM2   SDN-ADM2-3_0_0-B55
# 656             El Radoom      ADM2  SDN-ADM2-3_0_0-B142
# 681              El Rahad      ADM2  SDN-ADM2-3_0_0-B167
# 653           El Roseires      ADM2  SDN-ADM2-3_0_0-B139
# 642              El Salam      ADM2  SDN-ADM2-3_0_0-B128
# 632              El Salam      ADM2  SDN-ADM2-3_0_0-B118
# 647              El Salam      ADM2  SDN-ADM2-3_0_0-B133
# 597             El Sireaf      ADM2   SDN-ADM2-3_0_0-B83
# 547              El Souki      ADM2   SDN-ADM2-3_0_0-B33
# 598           El Taweisha      ADM2   SDN-ADM2-3_0_0-B84
# 637               El Tina      ADM2  SDN-ADM2-3_0_0-B123
# 599          Foro Baranga      ADM2   SDN-ADM2-3_0_0-B85
# 572               Gedaref      ADM2   SDN-ADM2-3_0_0-B58
# 133         Gedarif State      ADM1   SDN-ADM1-3_0_0-B14
# 666               Geissan      ADM2  SDN-ADM2-3_0_0-B152
# 622               Gereida      ADM2  SDN-ADM2-3_0_0-B108
# 132          Gezira State      ADM1   SDN-ADM1-3_0_0-B13
# 639              Ghubaysh      ADM2  SDN-ADM2-3_0_0-B125
# 537    Greater Wad Madani      ADM2   SDN-ADM2-3_0_0-B23
# 586                Habila      ADM2   SDN-ADM2-3_0_0-B72
# 600                Habila      ADM2   SDN-ADM2-3_0_0-B86
# 562               Halayeb      ADM2   SDN-ADM2-3_0_0-B48
# 664                 Halfa      ADM2  SDN-ADM2-3_0_0-B150
# 557      Halfa El Jadeeda      ADM2   SDN-ADM2-3_0_0-B43
# 559          Hamashkoreib      ADM2   SDN-ADM2-3_0_0-B45
# 566                  Haya      ADM2   SDN-ADM2-3_0_0-B52
# 580                Heiban      ADM2   SDN-ADM2-3_0_0-B66
# 515           Jabal Aulia      ADM2    SDN-ADM2-3_0_0-B1
# 563      Jabiet Al Maadin      ADM2   SDN-ADM2-3_0_0-B49
# 601            Jebel Moon      ADM2   SDN-ADM2-3_0_0-B87
# 535      Jebrat El Sheikh      ADM2   SDN-ADM2-3_0_0-B21
# 582               Kadugli      ADM2   SDN-ADM2-3_0_0-B68
# 604             Kalimendo      ADM2   SDN-ADM2-3_0_0-B90
# 519                Karari      ADM2    SDN-ADM2-3_0_0-B5
# 618                  Kass      ADM2  SDN-ADM2-3_0_0-B104
# 683               Kassala      ADM2  SDN-ADM2-3_0_0-B169
# 123         Kassala State      ADM1    SDN-ADM1-3_0_0-B4
# 626               Katayla      ADM2  SDN-ADM2-3_0_0-B112
# 602             Kebkabiya      ADM2   SDN-ADM2-3_0_0-B88
# 575                Keilak      ADM2   SDN-ADM2-3_0_0-B61
# 521              Khartoum      ADM2    SDN-ADM2-3_0_0-B7
# 517        Khartoum North      ADM2    SDN-ADM2-3_0_0-B3
# 131        Khartoum State      ADM1   SDN-ADM1-3_0_0-B12
# 677         Khashm Ghirba      ADM2  SDN-ADM2-3_0_0-B163
# 634                Kornoi      ADM2  SDN-ADM2-3_0_0-B120
# 553                 Kosti      ADM2   SDN-ADM2-3_0_0-B39
# 603               Kreinik      ADM2   SDN-ADM2-3_0_0-B89
# 625                 Kubum      ADM2  SDN-ADM2-3_0_0-B111
# 605                Kulbus      ADM2   SDN-ADM2-3_0_0-B91
# 606                 Kutum      ADM2   SDN-ADM2-3_0_0-B92
# 585                Lagawa      ADM2   SDN-ADM2-3_0_0-B71
# 668              Marshang      ADM2  SDN-ADM2-3_0_0-B154
# 607                Mellit      ADM2   SDN-ADM2-3_0_0-B93
# 532                Merawi      ADM2   SDN-ADM2-3_0_0-B18
# 573        Middle Gedaref      ADM2   SDN-ADM2-3_0_0-B59
# 608                Mukjar      ADM2   SDN-ADM2-3_0_0-B94
# 609               Nertiti      ADM2   SDN-ADM2-3_0_0-B95
# 621               Niteaga      ADM2  SDN-ADM2-3_0_0-B107
# 126    North Darfur State      ADM1    SDN-ADM1-3_0_0-B7
# 673           North Delta      ADM2  SDN-ADM2-3_0_0-B159
# 127  North Kordofan State      ADM1    SDN-ADM1-3_0_0-B8
# 136        Northern State      ADM1   SDN-ADM1-3_0_0-B17
# 633                 Nyala      ADM2  SDN-ADM2-3_0_0-B119
# 630           Nyala North      ADM2  SDN-ADM2-3_0_0-B116
# 560            Port Sudan      ADM2   SDN-ADM2-3_0_0-B46
# 571         Qala El Nahal      ADM2   SDN-ADM2-3_0_0-B57
# 552                 Rabak      ADM2   SDN-ADM2-3_0_0-B38
# 667        Rahad El Berdi      ADM2  SDN-ADM2-3_0_0-B153
# 645                Rashad      ADM2  SDN-ADM2-3_0_0-B131
# 130         Red Sea State      ADM1   SDN-ADM1-3_0_0-B11
# 581          Reif Ashargi      ADM2   SDN-ADM2-3_0_0-B67
# 124      River Nile State      ADM1    SDN-ADM1-3_0_0-B5
# 610                Rokoro      ADM2   SDN-ADM2-3_0_0-B96
# 558         Rural Kassala      ADM2   SDN-ADM2-3_0_0-B44
# 611            Saraf Omra      ADM2   SDN-ADM2-3_0_0-B97
# 545                Sennar      ADM2   SDN-ADM2-3_0_0-B31
# 125          Sennar State      ADM1    SDN-ADM1-3_0_0-B6
# 619     Sharg Jabel Marra      ADM2  SDN-ADM2-3_0_0-B105
# 518         Sharq El Nile      ADM2    SDN-ADM2-3_0_0-B4
# 623               Shattai      ADM2  SDN-ADM2-3_0_0-B109
# 669               Sheiria      ADM2  SDN-ADM2-3_0_0-B155
# 524                Shendi      ADM2   SDN-ADM2-3_0_0-B10
# 649               Shiekan      ADM2  SDN-ADM2-3_0_0-B135
# 549                 Singa      ADM2   SDN-ADM2-3_0_0-B35
# 672                Sinkat      ADM2  SDN-ADM2-3_0_0-B158
# 612                 Sirba      ADM2   SDN-ADM2-3_0_0-B98
# 533                Sodari      ADM2   SDN-ADM2-3_0_0-B19
# 120    South Darfur State      ADM1    SDN-ADM1-3_0_0-B1
# 121  South Kordofan State      ADM1    SDN-ADM1-3_0_0-B2
# 538    Southern El Gezira      ADM2   SDN-ADM2-3_0_0-B24
# 564                Suakin      ADM2   SDN-ADM2-3_0_0-B50
# 8                   Sudan      ADM0    SDN-ADM0-3_0_0-B1
# 658                 Sunta      ADM2  SDN-ADM2-3_0_0-B144
# 577                Talodi      ADM2   SDN-ADM2-3_0_0-B63
# 636               Tawilla      ADM2  SDN-ADM2-3_0_0-B122
# 686                Telkok      ADM2  SDN-ADM2-3_0_0-B172
# 554              Tendalti      ADM2   SDN-ADM2-3_0_0-B40
# 561                 Tokar      ADM2   SDN-ADM2-3_0_0-B47
# 670                Tullus      ADM2  SDN-ADM2-3_0_0-B156
# 662               Um Buru      ADM2  SDN-ADM2-3_0_0-B148
# 660              Um Dafug      ADM2  SDN-ADM2-3_0_0-B146
# 520             Um Durman      ADM2    SDN-ADM2-3_0_0-B6
# 539            Um El Qura      ADM2   SDN-ADM2-3_0_0-B25
# 648             Um Rawaba      ADM2  SDN-ADM2-3_0_0-B134
# 516             Umm Badda      ADM2    SDN-ADM2-3_0_0-B2
# 661            Umm Dukhun      ADM2  SDN-ADM2-3_0_0-B147
# 578            Umm Durein      ADM2   SDN-ADM2-3_0_0-B64
# 613           Umm Keddada      ADM2   SDN-ADM2-3_0_0-B99
# 551            Umm Ramtta      ADM2   SDN-ADM2-3_0_0-B37
# 536             Wad Banda      ADM2   SDN-ADM2-3_0_0-B22
# 684          Wad El Helew      ADM2  SDN-ADM2-3_0_0-B170
# 614            Wadi Salih      ADM2  SDN-ADM2-3_0_0-B100
# 122     West Darfur State      ADM1    SDN-ADM1-3_0_0-B3
# 137         West Kurdufan      ADM1   SDN-ADM1-3_0_0-B18
# 682    Western El Galabat      ADM2  SDN-ADM2-3_0_0-B168
# 685       Western Kassala      ADM2  SDN-ADM2-3_0_0-B171
# 134      White Nile State      ADM1   SDN-ADM1-3_0_0-B15
# 631                Yassin      ADM2  SDN-ADM2-3_0_0-B117
# 615              Zalingei      ADM2  SDN-ADM2-3_0_0-B101

# %%
dfb_fl_ea['location_count']=dfb_fl_ea.Location.str.count(',')
dfb_fl_ea['adm_lvl_count']=dfb_fl_ea['Adm Level'].str.count(';')
dfb_fl_ea['adm1_count']=dfb_fl_ea['Admin1 Code'].str.count(';')
dfb_fl_ea['adm2_count']=dfb_fl_ea['Admin2 Code'].str.count(';')
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# ## replacing GAUL Admin1 Code into GEOB admin2 codes

# %%
dfb_fl_ea['gaul_adm1_list']=dfb_fl_ea['Admin1 Code'].str.split(';')


em_dat_path='./'


gaul_adm1_dict_db=pd.read_csv(f'{em_dat_path}em_dat_ea_gaul_geob_adm1_codeshare.csv')

gaul_adm1_dict = dict(zip(gaul_adm1_dict_db.gaul_adm1_code, gaul_adm1_dict_db.geob_adm1_shapeID))


dfb_fl_ea_adm1=dfb_fl_ea[dfb_fl_ea['gaul_adm1_list'].notna()]

dfb_fl_ea_adm1['gaul_adm1_list_int']=dfb_fl_ea_adm1['gaul_adm1_list'].apply(lambda x: [int(i) for i in x])


dfb_fl_ea_adm1['gaul_adm1_geob'] = dfb_fl_ea_adm1['gaul_adm1_list_int'].apply(lambda x: [gaul_adm1_dict[i] for i in x])

#dfb_dr_adm1

dfb_fl_ea_adm1_a=dfb_fl_ea_adm1[['Dis No','gaul_adm1_geob']]

dfb_fl_ea_adm1_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 1033 to 4571
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dis No          99 non-null     object
#  1   gaul_adm1_geob  99 non-null     object
# dtypes: object(2)
# memory usage: 2.3+ KB

# %% [markdown]
#  ## replace adm1 code with adm2 sub codes

# %%
import geopandas as gp
import numpy as np

geob_adm1_adm2_filepath='./'


geob_db=gp.read_file(f'{geob_adm1_adm2_filepath}ea_adm2_geoboundaries_adm1_code.shp')


#https://stackoverflow.com/a/54137935/2501953


geob_db1=geob_db[['adm1_shape','shapeID']]
#geob_db2=geob_db1.set_index('adm1_shape')


#geob_db_dict=geob_db1['adm1_shape'].groupby(level=0).apply(lambda x: x.to_dict('shapeID')).to_dict()

geob_db2=geob_db1.groupby('adm1_shape').agg({'shapeID':lambda x: list(x)})
geob_db3=geob_db2.reset_index()
geob_db3.columns=['gaul_adm1_geob','shapeID']

geob_db3_dict = dict(zip(geob_db3.gaul_adm1_geob, geob_db3.shapeID))


dfb_fl_ea_adm1_a['geob_adm2'] = dfb_fl_ea_adm1_a['gaul_adm1_geob'].apply(lambda x: [geob_db3_dict[i] for i in x])

def flatten(l):
    return [item for sublist in l for item in sublist]

aa_list=[]
for idx,row in dfb_fl_ea_adm1_a.iterrows():
    aa=flatten(row['geob_adm2'])
    #print(aa)
    #dfb_dr_adm1_a.at[idx,'geob_adm2_list'] = list(flatten(row['geob_adm2']))
    aa_list.append(aa)
    aa=[]
    
dfb_fl_ea_adm1_a['geob_adm2_list']=aa_list
    
dfb_fl_part1=dfb_fl_ea_adm1_a[['Dis No','geob_adm2_list']]
dfb_fl_part1
# Out:
#              Dis No                                     geob_adm2_list
# 1033  2000-0259-SOM  [SOM-ADM2-3_0_0-B18, SOM-ADM2-3_0_0-B38, SOM-A...
# 1034  2000-0778-SOM  [SOM-ADM2-3_0_0-B17, SOM-ADM2-3_0_0-B40, SOM-A...
# 1046  2000-0790-TZA  [TZA-ADM2-3_0_0-B22, TZA-ADM2-3_0_0-B32, TZA-A...
# 1169  2001-0464-ETH  [ETH-ADM2-3_0_0-B2, ETH-ADM2-3_0_0-B38, ETH-AD...
# 1252  2002-0225-ETH  [ETH-ADM2-3_0_0-B70, ETH-ADM2-3_0_0-B71, ETH-A...
# 1371  2001-0672-RWA  [RWA-ADM2-3_0_0-B18, RWA-ADM2-3_0_0-B19, RWA-A...
# 1372  2001-0417-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 1442  2002-0273-RWA  [RWA-ADM2-3_0_0-B1, RWA-ADM2-3_0_0-B2, RWA-ADM...
# 1503  2002-0515-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 1509  2002-0715-SOM  [SOM-ADM2-3_0_0-B21, SOM-ADM2-3_0_0-B25, SOM-A...
# 1645  2003-0204-ETH  [ETH-ADM2-3_0_0-B1, ETH-ADM2-3_0_0-B14, ETH-AD...
# 1730  2003-0368-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 1786  2003-0204-SOM  [SOM-ADM2-3_0_0-B17, SOM-ADM2-3_0_0-B40, SOM-A...
# 1902  2004-0499-SOM  [SOM-ADM2-3_0_0-B3, SOM-ADM2-3_0_0-B28, SOM-AD...
# 1976  2005-0215-ETH  [ETH-ADM2-3_0_0-B13, ETH-ADM2-3_0_0-B1, ETH-AD...
# 1979  2005-0485-ETH  [ETH-ADM2-3_0_0-B6, ETH-ADM2-3_0_0-B15, ETH-AD...
# 2008  2005-0258-ETH                               [ETH-ADM2-3_0_0-B13]
# 2009  2005-0472-ETH  [ETH-ADM2-3_0_0-B4, ETH-ADM2-3_0_0-B7, ETH-ADM...
# 2078  2006-0204-ETH  [ETH-ADM2-3_0_0-B70, ETH-ADM2-3_0_0-B71, ETH-A...
# 2079  2006-0436-ETH  [ETH-ADM2-3_0_0-B11, ETH-ADM2-3_0_0-B19, ETH-A...
# 2081  2006-0442-ETH  [ETH-ADM2-3_0_0-B70, ETH-ADM2-3_0_0-B71, ETH-A...
# 2082  2006-0489-ETH  [ETH-ADM2-3_0_0-B2, ETH-ADM2-3_0_0-B38, ETH-AD...
# 2111  2005-0576-SDN  [SDN-ADM2-3_0_0-B46, SDN-ADM2-3_0_0-B47, SDN-A...
# 2115  2005-0215-KEN  [KEN-ADM2-3_0_0-B12, KEN-ADM2-3_0_0-B53, KEN-A...
# 2116  2005-0260-KEN  [KEN-ADM2-3_0_0-B1, KEN-ADM2-3_0_0-B23, KEN-AD...
# 2212  2006-0234-KEN  [KEN-ADM2-3_0_0-B58, KEN-ADM2-3_0_0-B12, KEN-A...
# 2296  2006-0229-SOM  [SOM-ADM2-3_0_0-B18, SOM-ADM2-3_0_0-B38, SOM-A...
# 2300  2006-0624-SOM  [SOM-ADM2-3_0_0-B21, SOM-ADM2-3_0_0-B25, SOM-A...
# 2313  2006-0624-TZA  [TZA-ADM2-3_0_0-B12, TZA-ADM2-3_0_0-B35, TZA-A...
# 2451  2007-0304-ETH  [ETH-ADM2-3_0_0-B48, ETH-ADM2-3_0_0-B70, ETH-A...
# 2514  2008-0386-ETH  [ETH-ADM2-3_0_0-B2, ETH-ADM2-3_0_0-B38, ETH-AD...
# 2611  2007-0261-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 2735  2008-0066-TZA  [TZA-ADM2-3_0_0-B9, TZA-ADM2-3_0_0-B27, TZA-AD...
# 2828  2008-0331-SSD  [SSD-ADM2-3_0_0-B37, SSD-ADM2-3_0_0-B38, SSD-A...
# 2829  2008-0520-SSD  [SSD-ADM2-3_0_0-B28, SSD-ADM2-3_0_0-B29, SSD-A...
# 2830  2008-0554-SSD  [SSD-ADM2-3_0_0-B15, SSD-ADM2-3_0_0-B16, SSD-A...
# 2909  2010-0450-ETH  [ETH-ADM2-3_0_0-B70, ETH-ADM2-3_0_0-B71, ETH-A...
# 2943  2009-0494-KEN  [KEN-ADM2-3_0_0-B12, KEN-ADM2-3_0_0-B53, KEN-A...
# 2946  2009-0484-TZA  [TZA-ADM2-3_0_0-B12, TZA-ADM2-3_0_0-B35, TZA-A...
# 2981  2009-0379-SDN  [SDN-ADM2-3_0_0-B73, SDN-ADM2-3_0_0-B74, SDN-A...
# 2990  2009-0591-TZA  [TZA-ADM2-3_0_0-B14, TZA-ADM2-3_0_0-B34, TZA-A...
# 3006  2010-0285-KEN            [KEN-ADM2-3_0_0-B4, KEN-ADM2-3_0_0-B43]
# 3045  2010-0319-SDN  [SDN-ADM2-3_0_0-B46, SDN-ADM2-3_0_0-B47, SDN-A...
# 3046  2010-0579-SDN  [SDN-ADM2-3_0_0-B8, SDN-ADM2-3_0_0-B9, SDN-ADM...
# 3055  2010-0115-SOM  [SOM-ADM2-3_0_0-B6, SOM-ADM2-3_0_0-B8, SOM-ADM...
# 3056  2010-0164-SOM  [SOM-ADM2-3_0_0-B35, SOM-ADM2-3_0_0-B58, SOM-A...
# 3169  2010-0579-SSD  [SSD-ADM2-3_0_0-B15, SSD-ADM2-3_0_0-B16, SSD-A...
# 3170  2010-0703-SSD  [SSD-ADM2-3_0_0-B28, SSD-ADM2-3_0_0-B29, SSD-A...
# 3302  2011-0634-TZA  [TZA-ADM2-3_0_0-B18, TZA-ADM2-3_0_0-B37, TZA-A...
# 3344  2011-0617-TZA  [TZA-ADM2-3_0_0-B86, TZA-ADM2-3_0_0-B97, TZA-A...
# 3383  2012-0280-SDN  [SDN-ADM2-3_0_0-B1, SDN-ADM2-3_0_0-B2, SDN-ADM...
# 3395  2012-0472-SOM  [SOM-ADM2-3_0_0-B18, SOM-ADM2-3_0_0-B38, SOM-A...
# 3411  2013-0123-KEN  [KEN-ADM2-3_0_0-B58, KEN-ADM2-3_0_0-B4, KEN-AD...
# 3455  2013-0280-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 3467  2013-0288-SOM  [SOM-ADM2-3_0_0-B5, SOM-ADM2-3_0_0-B14, SOM-AD...
# 3513  2012-0473-SSD  [SSD-ADM2-3_0_0-B15, SSD-ADM2-3_0_0-B16, SSD-A...
# 3529  2013-0425-SSD  [SSD-ADM2-3_0_0-B23, SSD-ADM2-3_0_0-B24, SSD-A...
# 3530  2013-0453-SSD  [SSD-ADM2-3_0_0-B23, SSD-ADM2-3_0_0-B24, SSD-A...
# 3611  2016-0101-ETH  [ETH-ADM2-3_0_0-B70, ETH-ADM2-3_0_0-B71, ETH-A...
# 3675  2014-0264-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 3682  2014-0456-SOM  [SOM-ADM2-3_0_0-B5, SOM-ADM2-3_0_0-B14, SOM-AD...
# 3721  2015-0392-SDN  [SDN-ADM2-3_0_0-B8, SDN-ADM2-3_0_0-B9, SDN-ADM...
# 3726  2015-0477-SOM  [SOM-ADM2-3_0_0-B27, SOM-ADM2-3_0_0-B29, SOM-A...
# 3727  2015-0544-SOM  [SOM-ADM2-3_0_0-B5, SOM-ADM2-3_0_0-B14, SOM-AD...
# 3746  2016-0129-SOM  [SOM-ADM2-3_0_0-B35, SOM-ADM2-3_0_0-B58, SOM-A...
# 3755  2014-0119-TZA  [TZA-ADM2-3_0_0-B11, TZA-ADM2-3_0_0-B25, TZA-A...
# 3790  2015-0205-TZA  [TZA-ADM2-3_0_0-B14, TZA-ADM2-3_0_0-B34, TZA-A...
# 3820  2016-0028-TZA  [TZA-ADM2-3_0_0-B12, TZA-ADM2-3_0_0-B35, TZA-A...
# 3940  2017-0205-KEN  [KEN-ADM2-3_0_0-B52, KEN-ADM2-3_0_0-B58, KEN-A...
# 3994  2018-0116-KEN                               [KEN-ADM2-3_0_0-B46]
# 4052  2016-0274-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 4072  2016-0327-SSD  [SSD-ADM2-3_0_0-B28, SSD-ADM2-3_0_0-B29, SSD-A...
# 4084  2017-0573-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 4094  2017-0205-TZA  [TZA-ADM2-3_0_0-B13, TZA-ADM2-3_0_0-B30, TZA-A...
# 4124  2018-0387-SDN  [SDN-ADM2-3_0_0-B1, SDN-ADM2-3_0_0-B2, SDN-ADM...
# 4127  2018-0292-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 4129  2018-0133-SOM  [SOM-ADM2-3_0_0-B10, SOM-ADM2-3_0_0-B13, SOM-A...
# 4140  2018-0125-TZA  [TZA-ADM2-3_0_0-B14, TZA-ADM2-3_0_0-B34, TZA-A...
# 4167  2019-0579-DJI  [DJI-ADM2-3_0_0-B10, DJI-ADM2-3_0_0-B7, DJI-AD...
# 4259  2019-0500-ETH  [ETH-ADM2-3_0_0-B1, ETH-ADM2-3_0_0-B14, ETH-AD...
# 4308  2020-0159-ETH  [ETH-ADM2-3_0_0-B13, ETH-ADM2-3_0_0-B3, ETH-AD...
# 4423  2019-0654-RWA  [RWA-ADM2-3_0_0-B1, RWA-ADM2-3_0_0-B2, RWA-ADM...
# 4424  2019-0392-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 4427  2019-0280-SDN  [SDN-ADM2-3_0_0-B78, SDN-ADM2-3_0_0-B79, SDN-A...
# 4431  2019-0500-SOM  [SOM-ADM2-3_0_0-B10, SOM-ADM2-3_0_0-B13, SOM-A...
# 4436  2019-0562-TZA  [TZA-ADM2-3_0_0-B22, TZA-ADM2-3_0_0-B32, TZA-A...
# 4439  2019-0496-TZA  [TZA-ADM2-3_0_0-B86, TZA-ADM2-3_0_0-B97, TZA-A...
# 4464  2019-0285-SSD  [SSD-ADM2-3_0_0-B1, SSD-ADM2-3_0_0-B2, SSD-ADM...
# 4471  2020-0041-RWA  [RWA-ADM2-3_0_0-B1, RWA-ADM2-3_0_0-B2, RWA-ADM...
# 4473  2020-0166-TZA  [TZA-ADM2-3_0_0-B14, TZA-ADM2-3_0_0-B34, TZA-A...
# 4480  2020-0305-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 4487  2020-0320-SOM  [SOM-ADM2-3_0_0-B10, SOM-ADM2-3_0_0-B13, SOM-A...
# 4488  2020-0159-SOM  [SOM-ADM2-3_0_0-B35, SOM-ADM2-3_0_0-B58, SOM-A...
# 4496  2020-0037-TZA  [TZA-ADM2-3_0_0-B10, TZA-ADM2-3_0_0-B31, TZA-A...
# 4497  2020-0458-TZA  [TZA-ADM2-3_0_0-B11, TZA-ADM2-3_0_0-B25, TZA-A...
# 4522  2020-0362-SSD  [SSD-ADM2-3_0_0-B15, SSD-ADM2-3_0_0-B16, SSD-A...
# 4541  2021-0473-SDN  [SDN-ADM2-3_0_0-B23, SDN-ADM2-3_0_0-B24, SDN-A...
# 4544  2021-0239-SOM  [SOM-ADM2-3_0_0-B35, SOM-ADM2-3_0_0-B58, SOM-A...
# 4571  2021-0481-SSD  [SSD-ADM2-3_0_0-B28, SSD-ADM2-3_0_0-B29, SSD-A...

# %% [markdown]
# ## replacing GAUL Admin2 Code into GEOB admin2 codes

# %%
dfb_fl_ea['gaul_adm2_list']=dfb_fl_ea['Admin2 Code'].str.split(';')


em_dat_path='./'


gaul_adm2_dict_db=pd.read_excel(f'{em_dat_path}em_dat_ea_gaul_geob_adm2_codeshare_v1.xlsx', engine='openpyxl')

gaul_adm2_dict = dict(zip(gaul_adm2_dict_db.gaul_adm2_code, gaul_adm2_dict_db.geob_adm2_shapeID))

gaul_adm2_dict[48481]='TZA-ADM1-3_0_0-B2'
gaul_adm2_dict[48451]='TZA-ADM1-3_0_0-B8'

#48481:TZA-ADM1-3_0_0-B2
#48451:TZA-ADM1-3_0_0-B8

dfb_fl_adm2=dfb_fl_ea[dfb_fl_ea['gaul_adm2_list'].notna()]

dfb_fl_adm2['gaul_adm2_list_int']=dfb_fl_adm2['gaul_adm2_list'].apply(lambda x: [int(i) for i in x])

#dfb_fl_adm2a=dfb_fl_adm2[dfb_fl_adm2['gaul_adm2_list_int']==48481]


dfb_fl_adm2['gaul_adm2_geob'] = dfb_fl_adm2['gaul_adm2_list_int'].apply(lambda x: [gaul_adm2_dict[i] for i in x])

# _b_dict={1:'TZA-ADM1-3_0_0-B2',2:'TZA-ADM1-3_0_0-B8'}

# dfb_fl_adm2['gaul_adm2_geob'] = dfb_fl_adm2['gaul_adm2_geob'].apply(lambda x: [_b_dict[i] for i in x])
# #dfb_dr_a

dfb_fl_part2=dfb_fl_adm2[['Dis No','gaul_adm2_geob']]

dfb_fl_part2.columns=['Dis No','geob_adm2_list']




dfb_fl_part2
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#              Dis No                                     geob_adm2_list
# 785   2000-0497-ETH                               [ETH-ADM2-3_0_0-B70]
# 796   2000-0399-ETH           [ETH-ADM2-3_0_0-B48, ETH-ADM2-3_0_0-B17]
# 910   2001-0032-KEN                               [KEN-ADM2-3_0_0-B46]
# 1033  2000-0259-SOM  [SOM-ADM2-3_0_0-B17, SOM-ADM2-3_0_0-B33, SOM-A...
# 1039  2000-0490-SOM                               [SOM-ADM2-3_0_0-B68]
# 1164  2001-0448-ETH                               [ETH-ADM2-3_0_0-B70]
# 1170  2001-0769-ETH                               [ETH-ADM2-3_0_0-B67]
# 1214  2002-0265-KEN  [KEN-ADM2-3_0_0-B20, KEN-ADM2-3_0_0-B44, KEN-A...
# 1270  2002-0711-KEN                               [KEN-ADM2-3_0_0-B18]
# 1271  2002-0689-KEN           [KEN-ADM2-3_0_0-B25, KEN-ADM2-3_0_0-B58]
# 1272  2002-0800-KEN                                [KEN-ADM2-3_0_0-B1]
# 1370  2001-0541-RWA                                [RWA-ADM2-3_0_0-B6]
# 1380  2001-0653-SOM                               [SOM-ADM2-3_0_0-B16]
# 1391  2001-0109-TZA  [TZA-ADM2-3_0_0-B25, TZA-ADM2-3_0_0-B11, TZA-A...
# 1442  2002-0273-RWA  [RWA-ADM2-3_0_0-B22, RWA-ADM2-3_0_0-B12, RWA-A...
# 1503  2002-0515-SDN  [SDN-ADM2-3_0_0-B126, SDN-ADM2-3_0_0-B128, SDN...
# 1509  2002-0715-SOM           [SOM-ADM2-3_0_0-B40, SOM-ADM2-3_0_0-B33]
# 1519  2002-0274-TZA            [TZA-ADM2-3_0_0-B50, TZA-ADM2-3_0_0-B4]
# 1613  2003-0204-KEN  [KEN-ADM2-3_0_0-B21, KEN-ADM2-3_0_0-B40, KEN-A...
# 1644  2003-0368-ERI                                [ERI-ADM2-3_0_0-B1]
# 1651  2003-0729-KEN                               [KEN-ADM2-3_0_0-B21]
# 1656  2004-0158-DJI                                [DJI-ADM2-3_0_0-B8]
# 1658  2004-0194-KEN  [KEN-ADM2-3_0_0-B57, KEN-ADM2-3_0_0-B58, KEN-A...
# 1661  2004-0394-ERI                               [ERI-ADM2-3_0_0-B14]
# 1710  2004-0152-KEN            [KEN-ADM2-3_0_0-B51, KEN-ADM2-3_0_0-B6]
# 1771  2003-0563-RWA           [RWA-ADM2-3_0_0-B22, RWA-ADM2-3_0_0-B24]
# 1787  2003-0447-SOM           [SOM-ADM2-3_0_0-B23, SOM-ADM2-3_0_0-B46]
# 1792  2003-0620-TZA                               [TZA-ADM2-3_0_0-B63]
# 2077  2006-0422-ETH           [ETH-ADM2-3_0_0-B13, ETH-ADM2-3_0_0-B48]
# 2080  2006-0438-ETH                               [ETH-ADM2-3_0_0-B56]
# 2083  2006-0578-ETH           [ETH-ADM2-3_0_0-B51, ETH-ADM2-3_0_0-B35]
# 2115  2005-0215-KEN           [KEN-ADM2-3_0_0-B13, KEN-ADM2-3_0_0-B69]
# 2116  2005-0260-KEN                               [KEN-ADM2-3_0_0-B69]
# 2117  2005-0526-KEN                                [KEN-ADM2-3_0_0-B6]
# 2165  2005-0748-SDN             [SDN-ADM2-3_0_0-B3, SDN-ADM2-3_0_0-B2]
# 2174  2005-0215-SOM  [SOM-ADM2-3_0_0-B35, SOM-ADM2-3_0_0-B38, SOM-A...
# 2175  2005-0309-SOM                               [SOM-ADM2-3_0_0-B33]
# 2186  2005-0212-TZA         [TZA-ADM2-3_0_0-B168, TZA-ADM2-3_0_0-B163]
# 2207  2006-0447-SDN                               [SDN-ADM2-3_0_0-B18]
# 2211  2006-0178-KEN  [KEN-ADM2-3_0_0-B13, KEN-ADM2-3_0_0-B42, KEN-A...
# 2213  2006-0587-KEN  [KEN-ADM2-3_0_0-B25, KEN-ADM1-3_0_0-B34, KEN-A...
# 2214  2006-0624-KEN  [KEN-ADM2-3_0_0-B19, KEN-ADM2-3_0_0-B25, KEN-A...
# 2284  2006-0422-SDN                               [SDN-ADM2-3_0_0-B30]
# 2285  2006-0442-SDN  [SDN-ADM2-3_0_0-B60, SDN-ADM2-3_0_0-B166, SDN-...
# 2297  2006-0422-SOM                               [SOM-ADM2-3_0_0-B72]
# 2298  2006-0550-SOM           [SOM-ADM2-3_0_0-B68, SOM-ADM2-3_0_0-B72]
# 2299  2006-0618-SOM  [SOM-ADM2-3_0_0-B38, SOM-ADM2-3_0_0-B18, SOM-A...
# 2312  2006-0255-TZA                               [TZA-ADM2-3_0_0-B78]
# 2362  2007-0059-RWA           [RWA-ADM2-3_0_0-B15, RWA-ADM2-3_0_0-B14]
# 2450  2007-0273-ETH                               [ETH-ADM2-3_0_0-B56]
# 2515  2008-0219-ETH                               [ETH-ADM2-3_0_0-B20]
# 2516  2008-0517-ETH  [ETH-ADM2-3_0_0-B25, ETH-ADM2-3_0_0-B1, ETH-AD...
# 2555  2007-0613-KEN                               [KEN-ADM2-3_0_0-B57]
# 2557  2007-0442-RWA           [RWA-ADM2-3_0_0-B15, RWA-ADM2-3_0_0-B14]
# 2559  2007-0408-KEN                                [KEN-ADM2-3_0_0-B6]
# 2560  2007-0425-SOM                               [SOM-ADM2-3_0_0-B72]
# 2567  2007-0177-KEN  [KEN-ADM2-3_0_0-B19, KEN-ADM2-3_0_0-B25, KEN-A...
# 2622  2007-0559-SOM                               [SOM-ADM2-3_0_0-B31]
# 2648  2008-0518-KEN  [KEN-ADM2-3_0_0-B58, KEN-ADM2-3_0_0-B69, KEN-A...
# 2649  2008-0485-RWA  [RWA-ADM2-3_0_0-B27, RWA-ADM2-3_0_0-B28, RWA-A...
# 2657  2008-0482-KEN                               [KEN-ADM2-3_0_0-B32]
# 2658  2008-0127-KEN                               [KEN-ADM2-3_0_0-B57]
# 2659  2008-0260-KEN                               [KEN-ADM2-3_0_0-B58]
# 2660  2008-0483-KEN                               [KEN-ADM2-3_0_0-B64]
# 2665  2008-0129-KEN           [KEN-ADM2-3_0_0-B35, KEN-ADM2-3_0_0-B53]
# 2721  2008-0506-SOM                               [SOM-ADM2-3_0_0-B42]
# 2730  2008-0127-TZA                              [TZA-ADM2-3_0_0-B157]
# 2828  2008-0331-SSD  [SSD-ADM2-3_0_0-B56, SSD-ADM2-3_0_0-B58, SSD-A...
# 2829  2008-0520-SSD  [SSD-ADM2-3_0_0-B78, SSD-ADM2-3_0_0-B70, SSD-A...
# 2908  2010-0115-ETH                               [ETH-ADM2-3_0_0-B51]
# 2943  2009-0494-KEN  [KEN-ADM2-3_0_0-B31, KEN-ADM2-3_0_0-B58, KEN-A...
# 2944  2009-0597-KEN  [KEN-ADM2-3_0_0-B18, KEN-ADM2-3_0_0-B19, KEN-A...
# 2985  2009-0532-SOM  [SOM-ADM2-3_0_0-B37, SOM-ADM2-3_0_0-B49, SOM-A...
# 2990  2009-0591-TZA  [TZA-ADM2-3_0_0-B49, TZA-ADM2-3_0_0-B35, TZA-A...
# 2998  2010-0094-KEN  [KEN-ADM2-3_0_0-B33, KEN-ADM2-3_0_0-B31, KEN-A...
# 3006  2010-0285-KEN                                [KEN-ADM2-3_0_0-B1]
# 3074  2011-0183-RWA  [RWA-ADM2-3_0_0-B5, RWA-ADM2-3_0_0-B20, RWA-AD...
# 3216  2011-0631-ETH                               [ETH-ADM2-3_0_0-B51]
# 3292  2013-0125-ETH  [ETH-ADM2-3_0_0-B53, ETH-ADM2-3_0_0-B29, ETH-A...
# 3314  2011-0423-KEN           [KEN-ADM2-3_0_0-B21, KEN-ADM2-3_0_0-B64]
# 3315  2011-0476-KEN                               [KEN-ADM2-3_0_0-B69]
# 3316  2011-0504-KEN  [KEN-ADM2-3_0_0-B44, KEN-ADM2-3_0_0-B58, KEN-A...
# 3341  2011-0476-SOM                               [SOM-ADM2-3_0_0-B68]
# 3343  2011-0535-TZA           [TZA-ADM2-3_0_0-B25, TZA-ADM2-3_0_0-B11]
# 3358  2012-0166-KEN  [KEN-ADM2-3_0_0-B61, KEN-ADM2-3_0_0-B31, KEN-A...
# 3382  2012-0130-RWA  [RWA-ADM2-3_0_0-B20, RWA-ADM2-3_0_0-B15, RWA-A...
# 3396  2012-0508-SOM                               [SOM-ADM2-3_0_0-B38]
# 3401  2012-0072-TZA                              [TZA-ADM2-3_0_0-B102]
# 3411  2013-0123-KEN  [KEN-ADM2-3_0_0-B18, KEN-ADM2-3_0_0-B44, KEN-A...
# 3414  2013-0281-KEN                                [KEN-ADM2-3_0_0-B1]
# 3415  2013-0305-KEN  [KEN-ADM2-3_0_0-B46, KEN-ADM2-3_0_0-B21, KEN-A...
# 3416  2013-0545-KEN  [KEN-ADM2-3_0_0-B57, KEN-ADM2-3_0_0-B30, KEN-A...
# 3468  2013-0473-SOM            [SOM-ADM2-3_0_0-B1, SOM-ADM2-3_0_0-B72]
# 3514  2012-0476-SSD                               [SSD-ADM2-3_0_0-B56]
# 3603  2015-0548-ETH                               [ETH-ADM2-3_0_0-B51]
# 3611  2016-0101-ETH           [ETH-ADM2-3_0_0-B20, ETH-ADM2-3_0_0-B68]
# 3612  2016-0186-ETH            [ETH-ADM2-3_0_0-B68, ETH-ADM2-3_0_0-B7]
# 3682  2014-0456-SOM  [SOM-ADM2-3_0_0-B15, SOM-ADM2-3_0_0-B25, SOM-A...
# 3689  2015-0153-RWA           [RWA-ADM2-3_0_0-B30, RWA-ADM2-3_0_0-B14]
# 3697  2015-0158-KEN                               [KEN-ADM2-3_0_0-B12]
# 3698  2015-0159-KEN  [KEN-ADM2-3_0_0-B46, KEN-ADM2-3_0_0-B8, KEN-AD...
# 3699  2015-0564-KEN  [KEN-ADM2-3_0_0-B20, KEN-ADM2-3_0_0-B58, KEN-A...
# 3731  2016-0149-RWA  [RWA-ADM2-3_0_0-B19, RWA-ADM2-3_0_0-B10, RWA-A...
# 3732  2016-0161-KEN  [KEN-ADM2-3_0_0-B35, KEN-ADM2-3_0_0-B46, KEN-A...
# 3736  2016-0089-KEN                               [KEN-ADM2-3_0_0-B64]
# 3754  2014-0042-TZA  [TZA-ADM2-3_0_0-B97, TZA-ADM2-3_0_0-B120, TZA-...
# 3755  2014-0119-TZA                               [TZA-ADM2-3_0_0-B50]
# 3819  2016-0060-TZA                              [TZA-ADM2-3_0_0-B104]
# 3820  2016-0028-TZA                              [TZA-ADM2-3_0_0-B104]
# 3821  2016-0244-TZA          [TZA-ADM2-3_0_0-B86, TZA-ADM2-3_0_0-B148]
# 3983  2018-0104-RWA                               [RWA-ADM2-3_0_0-B14]
# 3984  2018-0148-KEN                               [KEN-ADM2-3_0_0-B47]
# 3995  2018-0132-KEN  [KEN-ADM2-3_0_0-B58, KEN-ADM2-3_0_0-B13, KEN-A...
# 4120  2018-0135-RWA  [RWA-ADM2-3_0_0-B2, RWA-ADM2-3_0_0-B25, RWA-AD...
# 4124  2018-0387-SDN  [SDN-ADM2-3_0_0-B126, SDN-ADM2-3_0_0-B128, SDN...
# 4126  2018-0221-SDN          [SDN-ADM2-3_0_0-B74, SDN-ADM2-3_0_0-B101]
# 4127  2018-0292-SDN  [SDN-ADM2-3_0_0-B126, SDN-ADM2-3_0_0-B128, SDN...
# 4176  2019-0203-TZA  [TZA-ADM2-3_0_0-B25, TZA-ADM2-3_0_0-B11, TZA-A...
# 4220  2020-0150-DJI                                [DJI-ADM2-3_0_0-B8]
# 4250  2019-0500-KEN  [KEN-ADM2-3_0_0-B67, KEN-ADM2-3_0_0-B34, KEN-A...
# 4297  2020-0164-KEN  [KEN-ADM2-3_0_0-B20, KEN-ADM2-3_0_0-B19, KEN-A...
# 4310  2020-0564-ETH                               [ETH-ADM2-3_0_0-B55]
# 4373  2021-0227-KEN  [KEN-ADM2-3_0_0-B58, KEN-ADM2-3_0_0-B35, KEN-A...
# 4422  2019-0643-RWA  [RWA-ADM2-3_0_0-B5, RWA-ADM2-3_0_0-B20, RWA-AD...
# 4440  2019-0515-TZA                              [TZA-ADM2-3_0_0-B112]
# 4465  2019-0486-SSD                               [SSD-ADM2-3_0_0-B78]
# 4472  2020-0171-RWA  [RWA-ADM2-3_0_0-B25, RWA-ADM2-3_0_0-B22, RWA-A...
# 4480  2020-0305-SDN                               [SDN-ADM2-3_0_0-B54]
# 4481  2020-0098-RWA  [RWA-ADM2-3_0_0-B2, RWA-ADM2-3_0_0-B5, RWA-ADM...
# 4482  2020-0156-RWA  [RWA-ADM2-3_0_0-B19, RWA-ADM2-3_0_0-B22, RWA-A...
# 4488  2020-0159-SOM           [SOM-ADM2-3_0_0-B38, SOM-ADM2-3_0_0-B72]
# 4499  2020-0194-TZA                              [TZA-ADM2-3_0_0-B104]
# 4522  2020-0362-SSD  [SSD-ADM2-3_0_0-B63, SSD-ADM2-3_0_0-B56, SSD-A...
# 4524  2021-0282-RWA  [RWA-ADM2-3_0_0-B21, RWA-ADM2-3_0_0-B22, RWA-A...
# 4553  2021-0010-TZA                                [TZA-ADM1-3_0_0-B8]
# 4571  2021-0481-SSD           [SSD-ADM2-3_0_0-B63, SSD-ADM2-3_0_0-B66]
# 4573  2022-0055-RWA  [RWA-ADM2-3_0_0-B5, RWA-ADM2-3_0_0-B7, RWA-ADM...
# 4577  2022-0232-RWA  [RWA-ADM2-3_0_0-B2, RWA-ADM2-3_0_0-B26, RWA-AD...

# %%
import geopandas as gp
import glob

shpfiles=glob.glob(f'{shpfile_path}geoboundary_code_flood/*.shp')

for shpfl in shpfiles:
    db=gp.read_file(shpfl)
    db

# %%
db
# Out:
#            shapeName shapeISO  ... shapeType  \
# 0              Bomet    KE-02  ...      ADM1
# 1              Kisii    KE-16  ...      ADM1
# 2              Narok    KE-33  ...      ADM1
# 3           Homa Bay    KE-08  ...      ADM1
# 4             Migori    KE-27  ...      ADM1
# 5             Nakuru    KE-31  ...      ADM1
# 6            Kericho    KE-12  ...      ADM1
# 7             Kisumu    KE-17  ...      ADM1
# 8            Nyamira    KE-34  ...      ADM1
# 9              Siaya    KE-38  ...      ADM1
# 10             Busia    KE-04  ...      ADM1
# 11            Vihiga    KE-45  ...      ADM1
# 12           Baringo    KE-01  ...      ADM1
# 13           Bungoma    KE-03  ...      ADM1
# 14  Elegeyo-Marakwet    KE-05  ...      ADM1
# 15            Isiolo    KE-09  ...      ADM1
# 16          Kakamega    KE-11  ...      ADM1
# 17            Kiambu    KE-13  ...      ADM1
# 18         Kirinyaga    KE-15  ...      ADM1
# 19          Laikipia    KE-20  ...      ADM1
# 20           Mandera    KE-24  ...      ADM1
# 21          Marsabit    KE-25  ...      ADM1
# 22              Meru    KE-26  ...      ADM1
# 23             Nandi    KE-32  ...      ADM1
# 24         Nyandarua    KE-35  ...      ADM1
# 25             Nyeri    KE-36  ...      ADM1
# 26           Samburu    KE-37  ...      ADM1
# 27       Trans Nzoia    KE-42  ...      ADM1
# 28           Turkana    KE-43  ...      ADM1
# 29       Uasin Gishu    KE-44  ...      ADM1
# 30             Wajir    KE-46  ...      ADM1
# 31        West Pokot    KE-47  ...      ADM1
# 32          Murang`a    KE-29  ...      ADM1
#
#                                              geometry
# 0   POLYGON ((35.58631 -0.58674, 35.58790 -0.58973...
# 1   POLYGON ((35.00129 -0.89357, 34.98792 -0.89686...
# 2   POLYGON ((36.34809 -1.17494, 36.33735 -1.18696...
# 3   POLYGON ((35.02112 -0.41048, 35.02131 -0.41427...
# 4   POLYGON ((34.73151 -1.38936, 34.70255 -1.37307...
# 5   POLYGON ((36.59833 -0.99348, 36.59730 -0.99763...
# 6   POLYGON ((35.67573 -0.18947, 35.67471 -0.19001...
# 7   POLYGON ((35.34333 -0.23616, 35.34253 -0.23976...
# 8   POLYGON ((35.09192 -0.80324, 35.08932 -0.80612...
# 9   POLYGON ((34.55933 0.07128, 34.55933 0.06767, ...
# 10  POLYGON ((34.43470 0.73766, 34.43494 0.73406, ...
# 11  POLYGON ((34.92654 0.19785, 34.92554 0.19365, ...
# 12  POLYGON ((36.48670 0.84984, 36.48951 0.84606, ...
# 13  POLYGON ((35.06647 0.77073, 35.06595 0.76695, ...
# 14  POLYGON ((35.72291 0.22002, 35.72309 0.21526, ...
# 15  POLYGON ((39.46290 0.99187, 39.45911 0.98924, ...
# 16  POLYGON ((35.15589 0.68252, 35.15473 0.67171, ...
# 17  POLYGON ((37.36292 -1.09581, 37.35932 -1.10054...
# 18  POLYGON ((37.49415 -0.72835, 37.49610 -0.73176...
# 19  POLYGON ((37.39570 0.30004, 37.39332 0.29643, ...
# 20  POLYGON ((41.89958 3.97744, 41.87365 3.93795, ...
# 21  POLYGON ((39.34650 3.08446, 39.34589 3.06822, ...
# 22  POLYGON ((38.41993 -0.07136, 38.41730 -0.07466...
# 23  POLYGON ((35.43592 0.02483, 35.43891 0.01763, ...
# 24  POLYGON ((36.73334 -0.78047, 36.72992 -0.78016...
# 25  POLYGON ((37.30854 -0.15205, 37.27289 -0.24653...
# 26  POLYGON ((38.07929 0.78105, 38.07209 0.78105, ...
# 27  POLYGON ((35.36292 1.01702, 35.36329 1.01226, ...
# 28  POLYGON ((36.72529 2.29967, 36.72394 2.29528, ...
# 29  POLYGON ((35.59070 0.15249, 35.59131 0.14651, ...
# 30  POLYGON ((40.99466 0.46134, 40.98011 0.45067, ...
# 31  POLYGON ((35.78895 1.62883, 35.79090 1.62523, ...
# 32  POLYGON ((37.41871 -1.03834, 37.40387 -1.04883...
#
# [33 rows x 6 columns]

# %% [markdown]
# ## replacing manually added GEOB admin 1 and admin2 codes into common admin2 codes

# %%
import pandas as pd


dfb_fl=pd.read_excel(f'{em_dat_path}ea_flood_missing_location_v2.xlsx', engine='openpyxl')

dfb_fl1=dfb_fl[dfb_fl['geob'].isna()]

dfb_fl2=dfb_fl[dfb_fl['geob'].notna()]
dfb_fl2['geob_list']=dfb_fl2['geob'].str.split(',')

#dfb_dr1['geob_list']=dfb_dr1['geob'].str.split(',')

_ken=gp.read_file(f'{shpfile_path}geoboundary_code_flood/1998-0443-KEN.shp')

_ken_list=_ken['shapeID'].tolist()

_som94=gp.read_file(f'{shpfile_path}geoboundary_code_flood/1994-0573-SOM.shp')
_som94_list=_som94['shapeID'].tolist()

_som97=gp.read_file(f'{shpfile_path}geoboundary_code_flood/1997-0106-SOM.shp')
_som97_list=_som97['shapeID'].tolist()

dfb_fl1.at[38,'geob']=_ken_list
dfb_fl1.at[78,'geob']=_som94_list
dfb_fl1.at[81,'geob']=_som97_list

dfb_fl1a=dfb_fl1.rename(columns={"geob": "geob_list"})

dfb_fl_a=pd.concat([dfb_fl2,dfb_fl1a])
dfb_fl_a


def get_adm1_list(my_list):
    keys = ['ADM1','ADM2']
    aa=[[value for value in my_list if key in value] for key in set(keys)][0]
    bb=[[value for value in my_list if key in value] for key in set(keys)][1]
    #if not aa:
    #    bb=['']
    #else:
    #    bb=aa
    return aa,bb


aa_list=[]
bb_list=[]
for idx,row in dfb_fl_a.iterrows():
    #dfb_dr1.loc[idx,'geob_adm2_list'] = get_adm1_list(row['geob_list'])
    aa,bb=get_adm1_list(row['geob_list'])
    #dfb_dr1.loc[idx,'geob_adm2_list'] =aa
    #print(aa)
    aa_list.append(aa)
    bb_list.append(bb)

dfb_fl_a['geob_adm2_list']=bb_list
dfb_fl_a['geob_adm1_list']=aa_list


# dfb_dr1['geob_adm2'] = dfb_dr1['geob_list'].apply(lambda x: [geob_db3_dict[i] for i in x])
dfb_fl_adm1=dfb_fl_a[['Dis No','geob_adm1_list']]
#dfb_dr1_adm1_a=dfb_dr1_adm1[dfb_dr1_adm1['geob_adm1_list'].notna()]
dfb_fl_adm1_a=dfb_fl_adm1[dfb_fl_adm1['geob_adm1_list'].map(lambda d: len(d)) > 0]
dfb_fl_adm1_a['geob_adm2_list'] = dfb_fl_adm1_a['geob_adm1_list'].apply(lambda x: [geob_db3_dict[i] for i in x])


def flatten(l):
    return [item for sublist in l for item in sublist]

aa_list=[]
for idx,row in dfb_fl_adm1_a.iterrows():
    aa=flatten(row['geob_adm2_list'])
    aa_list.append(aa)
    #dfb_dr1_adm1_a.loc[idx,'geob_adm2_list_a'] = flatten(row['geob_adm2_list'])
    
dfb_fl_adm1_a['geob_adm2_list_a']=aa_list

dfb_fl_adm1_b=dfb_fl_adm1_a[['Dis No','geob_adm2_list_a']]

dfb_fl2=pd.merge(dfb_fl_a,dfb_fl_adm1_b,on='Dis No',how='left')

dfb_fl2['geob_adm2_list_a'] = dfb_fl2['geob_adm2_list_a'].apply(lambda d: d if isinstance(d, list) else [])

dfb_fl2['geob_adm2_list_a']=(dfb_fl2.geob_adm2_list+dfb_fl2.geob_adm2_list_a).map(set).map(list)

dfb_fl_part3=dfb_fl2[['Dis No','geob_adm2_list_a']]

dfb_fl_part3.columns=['Dis No','geob_adm2_list']

# %%
dfb_parts=pd.concat([dfb_fl_part1,dfb_fl_part2,dfb_fl_part3],axis=0)
dfb_parts1=dfb_parts.drop_duplicates('Dis No')

# %%
df=dfb_parts.groupby('Dis No').agg({'geob_adm2_list': 'sum'})

# %%
df_a=df[df['geob_adm2_list'].map(lambda d: len(d)) > 0]
adisno=df_a.index.tolist()

# %%
#df.to_csv('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_climada/ea-ibf-climada/impact_catalog/test.csv')

# %%
dfb_fl_ea1=dfb_fl_ea[~dfb_fl_ea['Dis No'].isin(adisno)]
df1=dfb_fl_ea1[['Dis No','Location']]
df1
#df1.to_csv('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/ea_climada/ea-ibf-climada/impact_catalog/fl_part4_missing_location.csv')
# Out:
#              Dis No                                           Location
# 33    1993-0503-DJI                                      Djibouti City
# 41    1990-0582-ETH                                     Gambela region
# 44    1990-0352-KEN                                                NaN
# 125   1993-0519-ETH                                   Near Addis Abeba
# 126   1993-0520-ETH                             Gollam, Gonder regions
# 155   1990-0016-TZA                              Lindi, Mtwara, Masasi
# 158   1990-0018-TZA  Moshi, Rombo districts (Kilimanjaro, Rukwa reg...
# 209   1993-0143-SDN                                         Port Sudan
# 474   1996-0473-SOM                                                NaN
# 4123  2018-0477-RWA                                                NaN
# 4362  2021-0343-ETH                                                NaN
# 4470  2020-0188-RWA  Gakenke (Northern province), Nyabihu, Muhangad...
# 4580  2022-0332-SOM                                  Galkayo district
# 4622  2022-0445-SDN  Kas District (South Darfur Stat); Kassala, Sou...
# 4631  2022-0258-TZA                           Mbeya and Songwe Regions

# %% [markdown]
# # part4 missing admins
# 1990-0352-KEN - http://erepository.uonbi.ac.ke/bitstream/handle/11295/66135/Alfred%20Opere.pdf?sequence
#
# 1996-0473-SOM - https://reliefweb.int/report/somalia/fews-bulletin-july-24-1996
#
# 2018-0477-RWA - https://reliefweb.int/disaster/fl-2018-000029-rwa
#
# 2021-0343-ETH - https://floodlist.com/tag/ethiopia
#
# Flood catalogs for EA from 1985
#
# https://drought.unl.edu/archive/Documents/NDMC/Workshops/539/Pres/GHA2_Policelli-floods-1.pdf

# %%
import geopandas as gp

_ken=gp.read_file(f'{shpfile_path}geoboundary_code_flood/1990-0352-KEN.shp')

print(_ken['shapeID'].tolist())
# Out:
# ['KEN-ADM2-3_0_0-B3', 'KEN-ADM2-3_0_0-B4', 'KEN-ADM2-3_0_0-B6', 'KEN-ADM2-3_0_0-B7', 'KEN-ADM2-3_0_0-B8', 'KEN-ADM2-3_0_0-B11', 'KEN-ADM2-3_0_0-B12', 'KEN-ADM2-3_0_0-B15', 'KEN-ADM2-3_0_0-B21', 'KEN-ADM2-3_0_0-B24', 'KEN-ADM2-3_0_0-B40', 'KEN-ADM2-3_0_0-B53', 'KEN-ADM2-3_0_0-B55', 'KEN-ADM2-3_0_0-B56', 'KEN-ADM2-3_0_0-B59', 'KEN-ADM2-3_0_0-B62', 'KEN-ADM2-3_0_0-B66', 'KEN-ADM2-3_0_0-B70']

# %%
_som=gp.read_file(f'{shpfile_path}geoboundary_code_flood/1996-0473-SOM.shp')

print(_som['shapeID'].tolist())
# Out:
# ['SOM-ADM2-3_0_0-B5', 'SOM-ADM2-3_0_0-B9', 'SOM-ADM2-3_0_0-B10', 'SOM-ADM2-3_0_0-B13', 'SOM-ADM2-3_0_0-B14', 'SOM-ADM2-3_0_0-B15', 'SOM-ADM2-3_0_0-B16', 'SOM-ADM2-3_0_0-B26', 'SOM-ADM2-3_0_0-B30', 'SOM-ADM2-3_0_0-B33', 'SOM-ADM2-3_0_0-B38', 'SOM-ADM2-3_0_0-B41', 'SOM-ADM2-3_0_0-B43', 'SOM-ADM2-3_0_0-B45', 'SOM-ADM2-3_0_0-B50', 'SOM-ADM2-3_0_0-B53', 'SOM-ADM2-3_0_0-B61', 'SOM-ADM2-3_0_0-B62', 'SOM-ADM2-3_0_0-B65', 'SOM-ADM2-3_0_0-B69']

# %%
_ken1=gp.read_file(f'{shpfile_path}geoboundary_code_flood/1996-0474-KEN.shp')

print(_ken1['shapeID'].tolist())
# Out:
# ['KEN-ADM2-3_0_0-B8', 'KEN-ADM2-3_0_0-B11', 'KEN-ADM2-3_0_0-B12', 'KEN-ADM2-3_0_0-B24', 'KEN-ADM2-3_0_0-B40', 'KEN-ADM2-3_0_0-B49', 'KEN-ADM2-3_0_0-B53', 'KEN-ADM2-3_0_0-B56', 'KEN-ADM2-3_0_0-B62']

# %% [markdown]
# ## part4 repalce

# %%
import pandas as pd
import geopandas as gp


geob_db=gp.read_file(f'ea_adm2_geoboundaries_adm1_code.shp')
#https://stackoverflow.com/a/54137935/2501953
geob_db1=geob_db[['adm1_shape','shapeID']]
#geob_db2=geob_db1.set_index('adm1_shape')
#geob_db_dict=geob_db1['adm1_shape'].groupby(level=0).apply(lambda x: x.to_dict('shapeID')).to_dict()
geob_db2=geob_db1.groupby('adm1_shape').agg({'shapeID':lambda x: list(x)})
geob_db3=geob_db2.reset_index()
geob_db3.columns=['gaul_adm1_geob','shapeID']
geob_db3_dict = dict(zip(geob_db3.gaul_adm1_geob, geob_db3.shapeID))


dfb_fl=pd.read_csv(f'fl_part4_missing_location_v1.csv')



dfb_fl1=dfb_fl[dfb_fl['geob'].notna()]
dfb_fl1['geob_list']=dfb_fl1['geob'].str.split(',').replace(' ','')



def get_adm1_list(my_list):
    keys = ['ADM1','ADM2']
    aa=[[value for value in my_list if key in value] for key in set(keys)][0]
    bb=[[value for value in my_list if key in value] for key in set(keys)][1]
    #if not aa:
    #    bb=['']
    #else:
    #    bb=aa
    return aa,bb


aa_list=[]
bb_list=[]
for idx,row in dfb_fl1.iterrows():
    #dfb_dr1.loc[idx,'geob_adm2_list'] = get_adm1_list(row['geob_list'])
    aa,bb=get_adm1_list(row['geob_list'])
    #dfb_dr1.loc[idx,'geob_adm2_list'] =aa
    #print(aa)
    aa_list.append(aa)
    bb_list.append(bb)

dfb_fl1['geob_adm2_list']=bb_list
dfb_fl1['geob_adm1_list']=aa_list


# dfb_dr1['geob_adm2'] = dfb_dr1['geob_list'].apply(lambda x: [geob_db3_dict[i] for i in x])
dfb_fl_adm1=dfb_fl1[['Dis No','geob_adm1_list']]
#dfb_dr1_adm1_a=dfb_dr1_adm1[dfb_dr1_adm1['geob_adm1_list'].notna()]
dfb_fl_adm1_a=dfb_fl_adm1[dfb_fl_adm1['geob_adm1_list'].map(lambda d: len(d)) > 0]
dfb_fl_adm1_a['geob_adm2_list'] = dfb_fl_adm1_a['geob_adm1_list'].apply(lambda x: [geob_db3_dict[i] for i in x])


def flatten(l):
    return [item for sublist in l for item in sublist]

aa_list=[]
for idx,row in dfb_fl_adm1_a.iterrows():
    aa=flatten(row['geob_adm2_list'])
    aa_list.append(aa)
    #dfb_dr1_adm1_a.loc[idx,'geob_adm2_list_a'] = flatten(row['geob_adm2_list'])
    
dfb_fl_adm1_a['geob_adm2_list_a']=aa_list

dfb_fl_adm1_b=dfb_fl_adm1_a[['Dis No','geob_adm2_list_a']]

dfb_fl2=pd.merge(dfb_fl1,dfb_fl_adm1_b,on='Dis No',how='left')

dfb_fl2['geob_adm2_list_a'] = dfb_fl2['geob_adm2_list_a'].apply(lambda d: d if isinstance(d, list) else [])

dfb_fl2['geob_adm2_list_a']=(dfb_fl2.geob_adm2_list+dfb_fl2.geob_adm2_list_a).map(set).map(list)

dfb_fl_part4=dfb_fl2[['Dis No','geob_adm2_list_a']]

dfb_fl_part4.columns=['Dis No','geob_adm2_list']
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
dfb_fl_part4
# Out:
#            Dis No                                     geob_adm2_list
# 0   1993-0503-DJI                                [DJI-ADM2-3_0_0-B8]
# 1   1990-0582-ETH  [ETH-ADM2-3_0_0-B38, ETH-ADM2-3_0_0-B2, ETH-AD...
# 2   1990-0352-KEN  [ KEN-ADM2-3_0_0-B40,  KEN-ADM2-3_0_0-B8,  KEN...
# 3   1993-0519-ETH                               [ETH-ADM2-3_0_0-B48]
# 4   1993-0520-ETH                               [ETH-ADM2-3_0_0-B63]
# 5   1990-0016-TZA  [TZA-ADM2-3_0_0-B38, TZA-ADM2-3_0_0-B132, TZA-...
# 6   1990-0018-TZA  [TZA-ADM2-3_0_0-B18,  TZA-ADM2-3_0_0-B78, TZA-...
# 7   1993-0143-SDN                               [SDN-ADM2-3_0_0-B46]
# 8   1993-0005-TZA          [TZA-ADM2-3_0_0-B13,  TZA-ADM2-3_0_0-B30]
# 9   1993-0157-TZA                               [TZA-ADM2-3_0_0-B30]
# 10  1994-0013-TZA                               [TZA-ADM2-3_0_0-B10]
# 11  1996-0474-KEN  [KEN-ADM2-3_0_0-B8,  KEN-ADM2-3_0_0-B40,  KEN-...
# 12  1997-0328-ETH                               [ETH-ADM2-3_0_0-B21]
# 13  1995-0317-SOM                               [SOM-ADM2-3_0_0-B68]
# 14  1996-0473-SOM  [ SOM-ADM2-3_0_0-B14, SOM-ADM2-3_0_0-B69,  SOM...
# 15  1997-0049-TZA                               [TZA-ADM2-3_0_0-B10]
# 16  1998-0096-TZA                               [TZA-ADM2-3_0_0-B55]
# 17  1999-0351-ETH  [ETH-ADM2-3_0_0-B38, ETH-ADM2-3_0_0-B2, ETH-AD...
# 18  1999-0419-ETH  [ETH-ADM2-3_0_0-B65, ETH-ADM2-3_0_0-B43, ETH-A...
# 19  1999-0316-SDN                               [SDN-ADM2-3_0_0-B15]
# 20  1999-0407-SDN                               [SDN-ADM2-3_0_0-B68]
# 21  2018-0477-RWA                               [RWA-ADM2-3_0_0-B14]
# 22  2021-0343-ETH                               [ETH-ADM2-3_0_0-B48]
# 23  2020-0188-RWA  [RWA-ADM2-3_0_0-B14, RWA-ADM2-3_0_0-B10, RWA-A...
# 24  2022-0332-SOM                                [SOM-ADM2-3_0_0-B4]
# 25  2022-0445-SDN  [SDN-ADM2-3_0_0-B144, SDN-ADM2-3_0_0-B124, SDN...
# 26  2022-0258-TZA  [TZA-ADM2-3_0_0-B142, TZA-ADM2-3_0_0-B144, TZA...

# %%
dfb_parts=pd.concat([dfb_fl_part1,dfb_fl_part2,dfb_fl_part3,dfb_fl_part4],axis=0)
#dfb_parts1=dfb_parts.drop_duplicates('Dis No')
df=dfb_parts.groupby('Dis No').agg({'geob_adm2_list': 'sum'})
df['len_of_list'] = df.geob_adm2_list.agg([len])
df['geob_adm2_list1'] = df['geob_adm2_list'].apply(lambda x: list(set(x)))
#df['len_of_list1'] = df.geob_un.agg([len])
df1=df[['geob_adm2_list1']]
df2=df1.reset_index()
df2.columns=['Dis No','geob_adm2_list']
df2.to_excel("em_dat_ea_flood_adm2_v0.xlsx",index=False)

# %%
df2
# Out:
#             Dis No                                     geob_adm2_list
# 0    1990-0016-TZA  [TZA-ADM2-3_0_0-B38, TZA-ADM2-3_0_0-B132, TZA-...
# 1    1990-0018-TZA  [TZA-ADM2-3_0_0-B18,  TZA-ADM2-3_0_0-B78, TZA-...
# 2    1990-0352-KEN  [ KEN-ADM2-3_0_0-B40,  KEN-ADM2-3_0_0-B8,  KEN...
# 3    1990-0582-ETH  [ETH-ADM2-3_0_0-B38, ETH-ADM2-3_0_0-B2, ETH-AD...
# 4    1993-0005-TZA  [TZA-ADM2-3_0_0-B13, TZA-ADM2-3_0_0-B30,  TZA-...
# ..             ...                                                ...
# 264  2022-0055-RWA  [RWA-ADM2-3_0_0-B17, RWA-ADM2-3_0_0-B14, RWA-A...
# 265  2022-0232-RWA  [RWA-ADM2-3_0_0-B2, RWA-ADM2-3_0_0-B16, RWA-AD...
# 266  2022-0258-TZA  [TZA-ADM2-3_0_0-B142, TZA-ADM2-3_0_0-B144, TZA...
# 267  2022-0332-SOM                                [SOM-ADM2-3_0_0-B4]
# 268  2022-0445-SDN  [SDN-ADM2-3_0_0-B144, SDN-ADM2-3_0_0-B124, SDN...
#
# [269 rows x 2 columns]
